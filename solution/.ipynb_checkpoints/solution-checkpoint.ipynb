# %% [markdown]
# #### Import libraries

# %%
import json
import pandas as pd
from pandas import json_normalize
import os
import numpy as np

# %% [markdown]
# #### Q1. Visualize the complete historical table view of each tables in tabular format in stdout (hint: print your table)

# %%
input_data = "/Users/edlynfrianto/Desktop/Interviews/MyOrange/DWH-Docker/solution/data"
folder_list = os.listdir(input_data)
for folder_name in folder_list:
    temp_df = pd.DataFrame()

    sorted_child_filename_list = sorted(os.listdir(input_data+"/"+folder_name))
    for filename in sorted_child_filename_list:
        with open(input_data+ "/"+folder_name+ "/"+ filename) as json_data:
            obj = json.load(json_data)
            if obj['op'] == 'c':
                df = json_normalize(obj['data'])
                df["global_"+folder_name+"_id"] = obj["id"]
                df["ts"] = obj["ts"]
                temp_df = pd.concat([temp_df, df])
            if obj['op'] == 'u':
                last_filtered_account = temp_df[temp_df["global_"+folder_name+'_id'] == obj['id']].tail(1)
                for key, value in obj["set"].items():
                    if value == "":
                        last_filtered_account[key] = np.nan
                    else:
                        last_filtered_account[key] = value

                last_filtered_account["ts"] = obj["ts"]
                temp_df = pd.concat([temp_df, last_filtered_account])
    
            
    # Translate back to df name
    if folder_name == "accounts":
        accounts_df = temp_df 
    elif folder_name == "cards":
        cards_df = temp_df 
    elif folder_name == "savings_accounts":
        savings_accounts_df = temp_df

# %%
accounts_df
# Out:
#   account_id     name   address phone_number                    email  \
# 0         a1  Anthony  New York     12345678     anthony@somebank.com
# 0         a1  Anthony  New York     87654321     anthony@somebank.com
# 0         a1  Anthony  New York     87654321     anthony@somebank.com
# 0         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 0         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 0         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 0         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
#
#   global_accounts_id             ts savings_account_id card_id
# 0         a1globalid  1577863800000                NaN     NaN
# 0         a1globalid  1577865600000                NaN     NaN
# 0         a1globalid  1577890800000                sa1     NaN
# 0         a1globalid  1577894400000                sa1     NaN
# 0         a1globalid  1577926800000                sa1      c1
# 0         a1globalid  1579078860000                sa1     NaN
# 0         a1globalid  1579163400000                sa1      c2

# %%
cards_df
# Out:
#   card_id card_number  credit_used  monthly_limit   status global_cards_id  \
# 0      c1    11112222            0          30000  PENDING      c1globalid
# 0      c1    11112222            0          30000   ACTIVE      c1globalid
# 0      c1    11112222        12000          30000   ACTIVE      c1globalid
# 0      c1    11112222        19000          30000   ACTIVE      c1globalid
# 0      c1    11112222            0          30000   ACTIVE      c1globalid
# 0      c1    11112222            0          30000   CLOSED      c1globalid
# 0      c2    12123434            0          70000  PENDING      c2globalid
# 0      c2    12123434            0          70000   ACTIVE      c2globalid
# 0      c2    12123434        37000          70000   ACTIVE      c2globalid
#
#               ts
# 0  1577926800000
# 0  1578159000000
# 0  1578313800000
# 0  1578420000000
# 0  1578654000000
# 0  1579078800000
# 0  1579163400000
# 0  1579298400000
# 0  1579361400000

# %%
savings_accounts_df
# Out:
#   savings_account_id  balance  interest_rate_percent  status  \
# 0                sa1        0                    1.5  ACTIVE
# 0                sa1    15000                    1.5  ACTIVE
# 0                sa1    15000                    3.0  ACTIVE
# 0                sa1    40000                    3.0  ACTIVE
# 0                sa1    21000                    3.0  ACTIVE
# 0                sa1    21000                    1.5  ACTIVE
# 0                sa1    21000                    4.0  ACTIVE
# 0                sa1    33000                    4.0  ACTIVE
#
#   global_savings_accounts_id             ts
# 0                sa1globalid  1577890800000
# 0                sa1globalid  1577955600000
# 0                sa1globalid  1578159060000
# 0                sa1globalid  1578648600000
# 0                sa1globalid  1578654000000
# 0                sa1globalid  1579078860000
# 0                sa1globalid  1579298460000
# 0                sa1globalid  1579505400000

# %% [markdown]
# #### Q2. Visualize the complete historical table view of the denormalized joined table in stdout by joining these three tables (hint: the join key lies in the resources section, please read carefully)

# %%
accounts_card_df = pd.merge(accounts_df, cards_df,  how='outer', left_on=['ts','card_id'], right_on = ['ts','card_id'])
accounts_card_df.rename(columns = {'status':'card_status'}, inplace = True)
accounts_card_df = accounts_card_df.sort_values(by=['ts'], ascending=True)
accounts_card_df = accounts_card_df.fillna(method='ffill')
accounts_card_df
# Out:
#    account_id     name   address phone_number                    email  \
# 0          a1  Anthony  New York     12345678     anthony@somebank.com
# 1          a1  Anthony  New York     87654321     anthony@somebank.com
# 2          a1  Anthony  New York     87654321     anthony@somebank.com
# 3          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 4          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 7          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 8          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 9          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 10         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 11         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 5          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 6          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 12         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 13         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
#
#    global_accounts_id             ts savings_account_id card_id card_number  \
# 0          a1globalid  1577863800000                NaN     NaN         NaN
# 1          a1globalid  1577865600000                NaN     NaN         NaN
# 2          a1globalid  1577890800000                sa1     NaN         NaN
# 3          a1globalid  1577894400000                sa1     NaN         NaN
# 4          a1globalid  1577926800000                sa1      c1    11112222
# 7          a1globalid  1578159000000                sa1      c1    11112222
# 8          a1globalid  1578313800000                sa1      c1    11112222
# 9          a1globalid  1578420000000                sa1      c1    11112222
# 10         a1globalid  1578654000000                sa1      c1    11112222
# 11         a1globalid  1579078800000                sa1      c1    11112222
# 5          a1globalid  1579078860000                sa1      c1    11112222
# 6          a1globalid  1579163400000                sa1      c2    12123434
# 12         a1globalid  1579298400000                sa1      c2    12123434
# 13         a1globalid  1579361400000                sa1      c2    12123434
#
#     credit_used  monthly_limit card_status global_cards_id
# 0           NaN            NaN         NaN             NaN
# 1           NaN            NaN         NaN             NaN
# 2           NaN            NaN         NaN             NaN
# 3           NaN            NaN         NaN             NaN
# 4           0.0        30000.0     PENDING      c1globalid
# 7           0.0        30000.0      ACTIVE      c1globalid
# 8       12000.0        30000.0      ACTIVE      c1globalid
# 9       19000.0        30000.0      ACTIVE      c1globalid
# 10          0.0        30000.0      ACTIVE      c1globalid
# 11          0.0        30000.0      CLOSED      c1globalid
# 5           0.0        30000.0      CLOSED      c1globalid
# 6           0.0        70000.0     PENDING      c2globalid
# 12          0.0        70000.0      ACTIVE      c2globalid
# 13      37000.0        70000.0      ACTIVE      c2globalid

# %%
accounts_card_savings_accounts_df = pd.merge(accounts_card_df, savings_accounts_df,  how='outer', left_on=['ts','savings_account_id'], right_on = ['ts','savings_account_id'])
accounts_card_savings_accounts_df.rename(columns = {'status':'savings_account_status'}, inplace = True)
accounts_card_savings_accounts_df = accounts_card_savings_accounts_df.sort_values(by=['ts'], ascending=True)
accounts_card_savings_accounts_df = accounts_card_savings_accounts_df.fillna(method='ffill')
accounts_card_savings_accounts_df
# Out:
#    account_id     name   address phone_number                    email  \
# 0          a1  Anthony  New York     12345678     anthony@somebank.com
# 1          a1  Anthony  New York     87654321     anthony@somebank.com
# 2          a1  Anthony  New York     87654321     anthony@somebank.com
# 3          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 4          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 14         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 5          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 15         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 6          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 7          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 16         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 8          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 9          a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 10         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 11         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 12         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 17         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 13         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
# 18         a1  Anthony   Jakarta     87654321  anthony@anotherbank.com
#
#    global_accounts_id             ts savings_account_id card_id card_number  \
# 0          a1globalid  1577863800000                NaN     NaN         NaN
# 1          a1globalid  1577865600000                NaN     NaN         NaN
# 2          a1globalid  1577890800000                sa1     NaN         NaN
# 3          a1globalid  1577894400000                sa1     NaN         NaN
# 4          a1globalid  1577926800000                sa1      c1    11112222
# 14         a1globalid  1577955600000                sa1      c1    11112222
# 5          a1globalid  1578159000000                sa1      c1    11112222
# 15         a1globalid  1578159060000                sa1      c1    11112222
# 6          a1globalid  1578313800000                sa1      c1    11112222
# 7          a1globalid  1578420000000                sa1      c1    11112222
# 16         a1globalid  1578648600000                sa1      c1    11112222
# 8          a1globalid  1578654000000                sa1      c1    11112222
# 9          a1globalid  1579078800000                sa1      c1    11112222
# 10         a1globalid  1579078860000                sa1      c1    11112222
# 11         a1globalid  1579163400000                sa1      c2    12123434
# 12         a1globalid  1579298400000                sa1      c2    12123434
# 17         a1globalid  1579298460000                sa1      c2    12123434
# 13         a1globalid  1579361400000                sa1      c2    12123434
# 18         a1globalid  1579505400000                sa1      c2    12123434
#
#     credit_used  monthly_limit card_status global_cards_id  balance  \
# 0           NaN            NaN         NaN             NaN      NaN
# 1           NaN            NaN         NaN             NaN      NaN
# 2           NaN            NaN         NaN             NaN      0.0
# 3           NaN            NaN         NaN             NaN      0.0
# 4           0.0        30000.0     PENDING      c1globalid      0.0
# 14          0.0        30000.0     PENDING      c1globalid  15000.0
# 5           0.0        30000.0      ACTIVE      c1globalid  15000.0
# 15          0.0        30000.0      ACTIVE      c1globalid  15000.0
# 6       12000.0        30000.0      ACTIVE      c1globalid  15000.0
# 7       19000.0        30000.0      ACTIVE      c1globalid  15000.0
# 16      19000.0        30000.0      ACTIVE      c1globalid  40000.0
# 8           0.0        30000.0      ACTIVE      c1globalid  21000.0
# 9           0.0        30000.0      CLOSED      c1globalid  21000.0
# 10          0.0        30000.0      CLOSED      c1globalid  21000.0
# 11          0.0        70000.0     PENDING      c2globalid  21000.0
# 12          0.0        70000.0      ACTIVE      c2globalid  21000.0
# 17          0.0        70000.0      ACTIVE      c2globalid  21000.0
# 13      37000.0        70000.0      ACTIVE      c2globalid  21000.0
# 18      37000.0        70000.0      ACTIVE      c2globalid  33000.0
#
#     interest_rate_percent savings_account_status global_savings_accounts_id
# 0                     NaN                    NaN                        NaN
# 1                     NaN                    NaN                        NaN
# 2                     1.5                 ACTIVE                sa1globalid
# 3                     1.5                 ACTIVE                sa1globalid
# 4                     1.5                 ACTIVE                sa1globalid
# 14                    1.5                 ACTIVE                sa1globalid
# 5                     1.5                 ACTIVE                sa1globalid
# 15                    3.0                 ACTIVE                sa1globalid
# 6                     3.0                 ACTIVE                sa1globalid
# 7                     3.0                 ACTIVE                sa1globalid
# 16                    3.0                 ACTIVE                sa1globalid
# 8                     3.0                 ACTIVE                sa1globalid
# 9                     3.0                 ACTIVE                sa1globalid
# 10                    1.5                 ACTIVE                sa1globalid
# 11                    1.5                 ACTIVE                sa1globalid
# 12                    1.5                 ACTIVE                sa1globalid
# 17                    4.0                 ACTIVE                sa1globalid
# 13                    4.0                 ACTIVE                sa1globalid
# 18                    4.0                 ACTIVE                sa1globalid

# %% [markdown]
# #### Q3. From result from point no 2, discuss how many transactions has been made, when did each of them occur, and how much the value of each transaction?
# #### Transaction is defined as activity which change the balance of the savings account or credit used of the card

# %%
transactions_df = accounts_card_savings_accounts_df[["ts","credit_used","balance"]]
transactions_df['diff_credit_used'] = transactions_df['credit_used'].diff()
transactions_df['diff_balance'] = transactions_df['balance'].diff()
transactions_df
# Out:
# /var/folders/vv/8sgh_t3j7bq4gm171plzwfy40000gn/T/ipykernel_12356/762509086.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactions_df['diff_credit_used'] = transactions_df['credit_used'].diff()
# /var/folders/vv/8sgh_t3j7bq4gm171plzwfy40000gn/T/ipykernel_12356/762509086.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactions_df['diff_balance'] = transactions_df['balance'].diff()
#                ts  credit_used  balance  diff_credit_used  diff_balance
# 0   1577863800000          NaN      NaN               NaN           NaN
# 1   1577865600000          NaN      NaN               NaN           NaN
# 2   1577890800000          NaN      0.0               NaN           NaN
# 3   1577894400000          NaN      0.0               NaN           0.0
# 4   1577926800000          0.0      0.0               NaN           0.0
# 14  1577955600000          0.0  15000.0               0.0       15000.0
# 5   1578159000000          0.0  15000.0               0.0           0.0
# 15  1578159060000          0.0  15000.0               0.0           0.0
# 6   1578313800000      12000.0  15000.0           12000.0           0.0
# 7   1578420000000      19000.0  15000.0            7000.0           0.0
# 16  1578648600000      19000.0  40000.0               0.0       25000.0
# 8   1578654000000          0.0  21000.0          -19000.0      -19000.0
# 9   1579078800000          0.0  21000.0               0.0           0.0
# 10  1579078860000          0.0  21000.0               0.0           0.0
# 11  1579163400000          0.0  21000.0               0.0           0.0
# 12  1579298400000          0.0  21000.0               0.0           0.0
# 17  1579298460000          0.0  21000.0               0.0           0.0
# 13  1579361400000      37000.0  21000.0           37000.0           0.0
# 18  1579505400000      37000.0  33000.0               0.0       12000.0

# %%
filtered_transactions_df = transactions_df[(transactions_df['diff_credit_used'] != 0.0) | (transactions_df['diff_balance'] != 0.0) ]
filtered_transactions_df = filtered_transactions_df[filtered_transactions_df[['diff_credit_used', 'diff_balance']].notnull().all(1)]
filtered_transactions_df
# Out:
#                ts  credit_used  balance  diff_credit_used  diff_balance
# 14  1577955600000          0.0  15000.0               0.0       15000.0
# 6   1578313800000      12000.0  15000.0           12000.0           0.0
# 7   1578420000000      19000.0  15000.0            7000.0           0.0
# 16  1578648600000      19000.0  40000.0               0.0       25000.0
# 8   1578654000000          0.0  21000.0          -19000.0      -19000.0
# 13  1579361400000      37000.0  21000.0           37000.0           0.0
# 18  1579505400000      37000.0  33000.0               0.0       12000.0
